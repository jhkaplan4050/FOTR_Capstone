# %% [markdown]
# ## Macrobenthic Data Reshaping for Timeline Map

# %%
! pip install pandas
! pip install numpy
# Out:
# Requirement already satisfied: pandas in /Users/kelsey/opt/anaconda3/lib/python3.8/site-packages (1.4.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/kelsey/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/kelsey/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/kelsey/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/kelsey/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /Users/kelsey/opt/anaconda3/lib/python3.8/site-packages (1.21.5)

# %%
import pandas as pd
import numpy as np

# %%
ben_sqi = pd.read_csv('../original_data/BENTHIC_MACROINVERTEBRATES_SQI.csv')

# %%
ben_sqi.head()
# Out:
#   FIELDID   Latitude  Longitude  F22 SQI  SP22 SQI  F21 SQI  SP21 SQI  \
# 0   Bish1  42.482378 -83.460553      NaN       NaN      NaN       NaN
# 1   Bish2  42.471310 -83.451510     38.0       NaN     21.0      28.0
# 2   Evan1  42.504517 -83.233388      NaN       NaN      NaN       NaN
# 3   Evan2  42.472955 -83.247905     20.0      16.0     14.0      12.0
# 4   Evan3  42.459278 -83.268639      NaN       NaN      2.0       0.0
#
#    F20 SQI  SP20 SQI  F19 SQI  ...  SP05 SQI  F04 SQI  SP04 SQI  F03 SQI  \
# 0      NaN       NaN      NaN  ...       NaN      NaN      15.0      NaN
# 1     20.0       NaN     23.0  ...       NaN      NaN       NaN      NaN
# 2      NaN       NaN      NaN  ...       NaN      NaN       NaN      NaN
# 3     21.0       NaN     16.0  ...       NaN      NaN       NaN      NaN
# 4      0.0       0.0      0.0  ...       NaN      NaN       NaN      NaN
#
#    SP03 SQI  F02 SQI  SP02 SQI  F01 SQI  SP01 SQI  Unnamed: 47
# 0      17.0      NaN      21.0      NaN      22.0          NaN
# 1       NaN      NaN       NaN      NaN       NaN          NaN
# 2       NaN      NaN       NaN      NaN       NaN          NaN
# 3       NaN      NaN       NaN      NaN       NaN          NaN
# 4       NaN      NaN       NaN      NaN       NaN          NaN
#
# [5 rows x 48 columns]

# %%
ben_sqi.drop(columns=['Unnamed: 47'], inplace=True)

# %%
ben_sqi_new = ben_sqi
ben_sqi_new.head()
# Out:
#   FIELDID   Latitude  Longitude  F22 SQI  SP22 SQI  F21 SQI  SP21 SQI  \
# 0   Bish1  42.482378 -83.460553      NaN       NaN      NaN       NaN
# 1   Bish2  42.471310 -83.451510     38.0       NaN     21.0      28.0
# 2   Evan1  42.504517 -83.233388      NaN       NaN      NaN       NaN
# 3   Evan2  42.472955 -83.247905     20.0      16.0     14.0      12.0
# 4   Evan3  42.459278 -83.268639      NaN       NaN      2.0       0.0
#
#    F20 SQI  SP20 SQI  F19 SQI  ...  F05 SQI  SP05 SQI  F04 SQI  SP04 SQI  \
# 0      NaN       NaN      NaN  ...      NaN       NaN      NaN      15.0
# 1     20.0       NaN     23.0  ...      NaN       NaN      NaN       NaN
# 2      NaN       NaN      NaN  ...      NaN       NaN      NaN       NaN
# 3     21.0       NaN     16.0  ...      NaN       NaN      NaN       NaN
# 4      0.0       0.0      0.0  ...      NaN       NaN      NaN       NaN
#
#    F03 SQI  SP03 SQI  F02 SQI  SP02 SQI  F01 SQI  SP01 SQI
# 0      NaN      17.0      NaN      21.0      NaN      22.0
# 1      NaN       NaN      NaN       NaN      NaN       NaN
# 2      NaN       NaN      NaN       NaN      NaN       NaN
# 3      NaN       NaN      NaN       NaN      NaN       NaN
# 4      NaN       NaN      NaN       NaN      NaN       NaN
#
# [5 rows x 47 columns]

# %%
### ADD THE NEWEST COLUMN NAME AS A STRING TO THIS LIST OF COLUMNS ###
unused_cols = ['FIELDID', 'Latitude', 'Longitude']

# %%
benthics_sqi = pd.DataFrame(columns=['FIELDID', 'Latitude', 'Longitude', 'Date', 'Season', 'SQI'], index=['FIELDID'])
for index, row in ben_sqi_new.iterrows():
    for col in ben_sqi_new.columns:
        # pull out sampling season
        if col in unused_cols:
            continue
        else:
            if col[0] == 'F':
                season = 'Fall'
                date = '10/15/' + col[1:3]
                # convert to datetime
                date_time = pd.to_datetime(date)
            else:
                season = 'Spring'
                date = '04/15/' + col[2:4]
                # convert to datetime
                date_time = pd.to_datetime(date)
            # pull out SQI value
            sqi = row[col]
            # compile row dict
            info = {'FIELDID':row['FIELDID'], 'Latitude':row['Latitude'], 'Longitude':row['Longitude'], 'Date':date_time, 'Season':season, 'SQI':sqi}
            info_df = pd.DataFrame(info, index=['Date'])
        # create new row for each sampling event
        benthics_sqi = pd.concat([benthics_sqi, info_df], ignore_index = True)

# %%
benthics_sqi.sample(5)
# Out:
#      FIELDID   Latitude  Longitude       Date  Season   SQI
# 2276   Main6  42.478820 -83.284548 2007-04-15  Spring  19.0
# 3290   MR-14  42.360143 -83.476375 2006-04-15  Spring   NaN
# 4549    See2  42.489270 -83.400990 2014-10-15    Fall  24.0
# 4300    Mur2  42.593750 -83.251740 2007-04-15  Spring  25.0
# 337     Fel4  42.313460 -83.464710 2008-10-15    Fall  32.0

# %%
benthics_sqi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5589 entries, 0 to 5588
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FIELDID    5588 non-null   object
#  1   Latitude   5588 non-null   float64
#  2   Longitude  5588 non-null   float64
#  3   Date       5588 non-null   datetime64[ns]
#  4   Season     5588 non-null   object
#  5   SQI        1774 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 262.1+ KB

# %%
benthics_sqi.dropna(inplace=True)

# %%
benthics_sqi['SQI'] = benthics_sqi['SQI'].astype(int)

# %%
bins = [-1, 19, 33, 48, np.inf]
names = ['Poor', 'Fair', 'Good', 'Excellent']

benthics_sqi['SQI Rating'] = pd.cut(benthics_sqi['SQI'], bins, labels=names)

# %%
benthics_sqi.drop_duplicates(inplace=True)

# %%
benthics_sqi.head()
# Out:
#    FIELDID   Latitude  Longitude       Date  Season  SQI SQI Rating
# 38   Bish1  42.482378 -83.460553 2004-04-15  Spring   15       Poor
# 40   Bish1  42.482378 -83.460553 2003-04-15  Spring   17       Poor
# 42   Bish1  42.482378 -83.460553 2002-04-15  Spring   21       Fair
# 44   Bish1  42.482378 -83.460553 2001-04-15  Spring   22       Fair
# 45   Bish2  42.471310 -83.451510 2022-10-15    Fall   38       Good

# %%
benthics_sqi.to_csv('../modified_data/benthics/benthics_reshaped_full.csv')

# %%
benthics_sqi_fall = benthics_sqi[benthics_sqi.Season != "Spring"]
benthics_sqi_fall.head()
# Out:
#    FIELDID  Latitude  Longitude       Date Season  SQI SQI Rating
# 45   Bish2  42.47131  -83.45151 2022-10-15   Fall   38       Good
# 47   Bish2  42.47131  -83.45151 2021-10-15   Fall   21       Fair
# 49   Bish2  42.47131  -83.45151 2020-10-15   Fall   20       Fair
# 51   Bish2  42.47131  -83.45151 2019-10-15   Fall   23       Fair
# 55   Bish2  42.47131  -83.45151 2017-10-15   Fall   20       Fair

# %%
benthics_sqi_fall.to_csv('../modified_data/benthics/benthics_reshaped_fall.csv')

# %%
benthics_sqi_spring = benthics_sqi[benthics_sqi.Season != "Fall"]
benthics_sqi_spring.head()
# Out:
#    FIELDID   Latitude  Longitude       Date  Season  SQI SQI Rating
# 38   Bish1  42.482378 -83.460553 2004-04-15  Spring   15       Poor
# 40   Bish1  42.482378 -83.460553 2003-04-15  Spring   17       Poor
# 42   Bish1  42.482378 -83.460553 2002-04-15  Spring   21       Fair
# 44   Bish1  42.482378 -83.460553 2001-04-15  Spring   22       Fair
# 48   Bish2  42.471310 -83.451510 2021-04-15  Spring   28       Fair

# %%
benthics_sqi_spring.to_csv('../modified_data/benthics/benthics_reshaped_spring.csv')
